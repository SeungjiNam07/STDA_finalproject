# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/seungji/Downloads/서울특별시 코로나19 자치구별 확진자 발생동향.csv',encoding = 'cp949')

# %%
data['자치구 기준일'].unique()
# Out:
# array(['2021.12.05.00', '2021.12.04.00', '2021.12.03.00', '2021.12.02.00',
#        '2021.12.01.00', '2021.11.30.00', '2021.11.29.00', '2021.11.28.00',
#        '2021.11.27.00', '2021.11.26.00', '2021.11.25.00', '2021.11.24.00',
#        '2021.11.23.00', '2021.11.22.00', '2021.11.21.00', '2021.11.20.00',
#        '2021.11.19.00', '2021.11.18.00', '2021.11.17.00', '2021.11.16.00',
#        '2021.11.15.00', '2021.11.08.00', '2021.11.07.00', '2021.11.06.00',
#        '2021.11.05.00', '2021.11.04.00', '2021.11.03.00', '2021.11.02.00',
#        '2021.11.01.00', '2021.10.31.00', '2021.10.30.00', '2021.10.29.00',
#        '2021.10.28.00', '2021.10.27.00', '2021.10.26.00', '2021.10.25.00',
#        '2021.10.24.00', '2021.10.23.00', '2021.10.22.00', '2021.10.21.00',
#        '2021.10.20.00', '2021.10.19.00', '2021.10.18.00', '2021.10.17.00',
#        '2021.10.16.00', '2021.10.15.00', '2021.10.14.00', '2021.10.13.00',
# ...

# %%
corona = data[(-data['종로구 전체'].isnull())&(data['자치구 기준일']>='2021-01-07')]

# %%
corona
# Out:
#            자치구 기준일  종로구 전체  종로구 추가   중구 전체  중구 추가  용산구 전체  용산구 추가  성동구 전체  \
# 0    2021.12.05.00  2977.0    27.0  2841.0   33.0  4067.0    48.0  4317.0
# 1    2021.12.04.00  2950.0    66.0  2808.0   29.0  4019.0    48.0  4280.0
# 2    2021.12.03.00  2884.0    29.0  2779.0   22.0  3971.0    50.0  4246.0
# 3    2021.12.02.00  2850.0    33.0  2757.0   41.0  3919.0    48.0  4203.0
# 4    2021.12.01.00  2783.0    44.0  2684.0   36.0  3851.0    75.0  4149.0
# ..             ...     ...     ...     ...    ...     ...     ...     ...
# 329  2021.01.05.00   426.0     4.0   286.0    1.0   433.0     4.0   473.0
# 330  2021.01.04.00   422.0     4.0   285.0    2.0   429.0     1.0   469.0
# 331  2021.01.03.00   418.0     4.0   283.0    0.0   428.0     3.0   460.0
# 332  2021.01.02.00   414.0    10.0   283.0    1.0   425.0     7.0   460.0
# 333  2021.01.01.00   404.0    11.0   282.0    1.0   418.0     2.0   450.0
#
#      성동구 추가  광진구 전체  ...  서추구 추가  강남구 전체  강남구 추가  송파구 전체  송파구 추가  강동구 전체  \
# ...
